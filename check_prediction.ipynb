# %%
import h5py
filename = 'zero_model.h5'
f = h5py.File(filename, 'r')

# List all groups
print("Keys: %s" % f.keys())
a_group_key = list(f.keys())[0]

# Get the data
data = list(f[a_group_key])
# Out:
# Keys: [u'model_weights', u'optimizer_weights']

# %%
from keras.models import load_model
model = load_model('zero_model.h5')

# %%
import pandas as pd
import numpy as np
import keras

# %%
df = pd.read_csv('data/review_dataset.csv')
df.head()
df.tail()
# Out:
#                                                  review cat
# 1964                            The cost was ridiculous  FO
# 1965                Check in - good, quick and friendly  FO
# 1966  Wifi - worked much better on mid floor, maybe ...  FO
# 1967                          Great room, very spacious  FO
# 1968                            Room are big and quite.  FO

# %%
from keras.preprocessing.text import text_to_word_sequence
# define the document
text = 'The quick brown fox jumped over the lazy dog.'
# tokenize the document
result = text_to_word_sequence(df['review'][0])
print(result)
# Out:
# ['much', 'better', 'than', 'the', 'west', 'hollywood', 'property', 'where', 'brand', 'standards', 'are', 'slowly', 'fading']

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

t = Tokenizer()
# fit the tokenizer on the documents
t.fit_on_texts(str(df['review']))

# %%
example = t.texts_to_sequences(str(df['review']))
example = pad_sequences(example, maxlen=128)

incorrects = []
pred = model.predict(example)

print type(pred)
# Out:
# <type 'numpy.ndarray'>

# %%
header = ['FB', 'FO', 'HK', 'HOTEL']
df2 = pd.DataFrame(pred)

# %%
df2.columns = header
df2.head()
# Out:
#          FB        FO        HK     HOTEL
# 0  0.220835  0.234757  0.200642  0.343766
# 1  0.240030  0.259543  0.209512  0.290916
# 2  0.240030  0.259543  0.209512  0.290916
# 3  0.240030  0.259543  0.209512  0.290916
# 4  0.240030  0.259543  0.209512  0.290916

# %%
df['FB'] = df2['FB']
df['FO'] = df2['FO']
df['HK'] = df2['HK']
df['HO'] = df2['HOTEL']

df.tail()
# Out:
#                                                  review cat        FB  \
# 1964                            The cost was ridiculous  FO  0.228035
# 1965                Check in - good, quick and friendly  FO  0.127246
# 1966  Wifi - worked much better on mid floor, maybe ...  FO  0.120385
# 1967                          Great room, very spacious  FO  0.219771
# 1968                            Room are big and quite.  FO  0.241675
#
#             FO        HK        HO
# 1964  0.263125  0.189905  0.318935
# 1965  0.296980  0.160149  0.415625
# 1966  0.581263  0.128022  0.170330
# 1967  0.261990  0.178222  0.340017
# 1968  0.263211  0.180001  0.315112

# %%
display = open("outhtml/correct.html", 'w')
html = """<HTML>
<style>
table{{font-family: arial, sans-serif;
    border-collapse: collapse;
    width: 100%;}}
    
td,th{{border: 1px solid #dddddd;
    text-align: left;
    padding: 8px;}}
tr:nth-child(even) {{
    background-color: #dddddd;
}}
</style>
<body>
    <h1 style="text-align:center;">Prediction Table</h1>
    <table style="border-color:black;">
        <tr>
            <th>Review</th>
            <th>Label</th>
            <th>Food/Beverage</th>
            <th>Front Offc</th>
            <th>House Keeping</th>
            <th>Hotel</th>
        </tr>
        {0}
    </table>
</body>
</HTML>"""

items = li
tr = "<tr>{0}</tr>"
td = "<td>{0}</td>"
subitem = [tr.format(''.join([td.format(a) for a in item])) for item in items]
print html.format("".join(subitems))
display.write(html.format(''.join(subitem)))
# Out:
# <HTML>
# <style>
# table{font-family: arial, sans-serif;
#     border-collapse: collapse;
#     width: 100%;}
#
# td,th{border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;}
# tr:nth-child(even) {
#     background-color: #dddddd;
# }
# </style>
# <body>
#     <h1 style="text-align:center;">Prediction Table</h1>
#     <table style="border-color:black;">
#         <tr>
#             <th>Review</th>
#             <th>Label</th>
#             <th>Food/Beverage</th>
#             <th>Front Offc</th>
#             <th>House Keeping</th>
#             <th>Hotel</th>
#         </tr>
#         <tr><td>MUCH better than the West Hollywood property where Brand standards are slowly fading.Hotel</td></tr><tr><td>Stay away from room service in my opinion....Hotel</td></tr><tr><td>Room service was superb.Hotel</td></tr><tr><td>Stayed in a king suite for 11 nights and yes it cots us a bit but we were happy with the standard of room, the location and the friendliness of the staff.Hotel</td></tr><tr><td>The location close to the 72nd Street subway station is great and the complimentary umbrellas on the drizzly days were greatly appreciated.Hotel</td></tr><tr><td>This is the second time that members of the party have stayed at the Beacon and it will certainly be our hotel of choice for future visits.Hotel</td></tr><tr><td>The staff are so accommodating and just love walking across the street to the Fairway supermarket with every imaginable goodies to eat (if you choose not to go out for every meal!)Hotel</td></tr><tr><td>This is a great property in Midtown.Hotel</td></tr><tr><td>The Hyatt has come up with a modern hotel that is both comfortable and convenient.Hotel</td></tr><tr><td>As a hotel designer and someone who is very picky about hotels, I will definitely stay there again and I highly recommend it.Hotel</td></tr><tr><td>I have stayed at each of the US Andaz properties, and this one is the best of them all.Hotel</td></tr><tr><td>This is the shining star here in the States.Hotel</td></tr><tr><td>Really great for a longer stay...Hotel</td></tr><tr><td>The waits were sometimes ridiculous.Hotel</td></tr><tr><td>3 elevators serve the main tower with a rather limited number of rooms.Hotel</td></tr><tr><td>THis is a newer hotel, but there is no service elevator.Hotel</td></tr><tr><td>I was continually surprised after waiting for an elevator at how many stops we made for housekeeping to enter with carts, room service carts and trays, etc.Hotel</td></tr><tr><td>How could Hyatt skip a service elevator on this new property?Hotel</td></tr><tr><td>It really stinks at times.....its bad.Hotel</td></tr><tr><td>This one really surprised me, and i have traveled the world for more than 20 years staying in some of the finest hotels in the world.Hotel</td></tr><tr><td>Andaz is great, but it doesn't rank with many that i have had the pleasure of staying with.Hotel</td></tr><tr><td>It was half the cost....almost.Hotel</td></tr><tr><td>Honestly will have trouble staying at any other hotel in the NYC area.Hotel</td></tr><tr><td>For those who stay at this hotel, there's always a chance at a celebrity sighting.Hotel</td></tr><tr><td>I stayed at the Setai for 3 nights last week, as my company reserved a block for us.Hotel</td></tr><tr><td>I have stayed at countless hotels in NYC and this is by far the best value.Hotel</td></tr><tr><td>My boss is very hard to impress and he has already mentioned he would like to book again next year.Hotel</td></tr><tr><td>My husband and I stayed at The Chatwal for 9 nights in April 2012.Hotel</td></tr><tr><td>We booked our rooms via booking.com.Hotel</td></tr><tr><td>It is just like the photos in the hotel website.Hotel</td></tr><tr><td>We thank Mr Mullins for all his help.Hotel</td></tr><tr><td>Overall a great 5-star boutique hotel experience in a very central NYC location.Hotel</td></tr><tr><td>Subway is two blocks away to all of Manhattan.Hotel</td></tr><tr><td>The hotel also has a great view of the Empire State Building in rooms facing 6th Ave.Hotel</td></tr><tr><td>I was extremely satisfied with the my two night's stay and would stay again.Hotel</td></tr><tr><td>I've stayed at 4 and 5 star hotels all over Manhattan.Hotel</td></tr><tr><td>Over the past year, however, I have returned each time to the Eventi.Hotel</td></tr><tr><td>Stayed at this hotel for four nights in December 2012.Hotel</td></tr><tr><td>With regard the hotel itself, we were very happy with out choice.Hotel</td></tr><tr><td>The hotel has two lifts servicing all floor, and we never had to wait for a lift.Hotel</td></tr><tr><td>Hotel was v ...
#     </table>
# </body>
# </HTML>
