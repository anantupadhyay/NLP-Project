# %%
 # -*- coding: utf-8 -*-

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
import numpy as np
import datetime
import json
import re
import csv
import math
from split_words import split_words, EMOJIS, BULLETS, APPOSTOPHES

# %%
def loadGloveModel(gloveFile):
    f = open(gloveFile, 'r')
    model = {}
    for line in f:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print "Trained Model", len(model), " words loaded!"
    return model

# %%
model = loadGloveModel('dataset/glove/glove.6B.300d.txt')
# Out:
# Trained Model 400000  words loaded!

# %%
# Defining the clean function
def clean_review(original_review):

	review=original_review.lower()


	for k in APPOSTOPHES:
		review = review.replace(k, APPOSTOPHES[k])

	#to remove multiple dots in string
	review = re.sub('\.\.+', '. ', review)

	#split a.a, a.A,a.1 not 1.1
	review = re.sub(r"([a-zA-Z])\.([a-zA-Z0-9])", "\\1. \\2", review)
	review = re.sub(r"([0-9])\.([a-zA-Z])", "\\1 . \\2", review)
	review = re.sub(r"([a-zA-Z])\\([a-zA-Z0-9])", "\\1 or \\2", review)

	review = re.sub('(?!^)([A-Z][a-z]+)', r' \1', review)
	
	#remove multiple occurance of words eg. woooooo=>woo
	review = re.sub(r"([a-zA-Z])\1+", r"\1\1", review)

	review = review.replace("!",'. ')
	review = review.replace(":",' : ')
	review = re.sub(r'\?+', "?", review)

	review=review.replace("\n",". ")
	review=re.sub(' +',' ',review)

	return str(review)

# %%
with open('dataset/stopwords.txt') as f:
    content = f.readlines()
stop_words = [x.strip() for x in content]
print len(stop_words)
# Out:
# 253

# %%
dset = pd.read_csv('dataset/review-dump.csv')
df = pd.read_csv('dataset/video_details.csv')

# %%
# Creating data by removing stop_words
li_stop = []
dset['review'] = dset['review'].astype('str')
for x in range(0, len(dset['review'])):
    words = dset['review'][x].split()
    tmp = [word for word in words if word.lower() not in stop_words]
    res = ' '.join(tmp)
    li_stop.append(res)

print len(li_stop)
dset_new = pd.DataFrame(li_stop)
dset_new.columns = ['review']
# Out:
# 1969

# %%
def train_tfidf(dset):
    porter = nltk.PorterStemmer()
    doc = []
    dset['review'] = dset['review'].astype('str')
    for x in dset['review']:
        x = x.decode('utf-8')
        x.encode('ascii', 'ignore')
        tokens = word_tokenize(x.lower())
        stem = [porter.stem(t) for t in tokens]
        doc.append(' '.join(stem))
    # print doc
    vectorizer = TfidfVectorizer(ngram_range=(1,3))
    vectorizer.fit(doc)
    print len(vectorizer.vocabulary_)
    return vectorizer

vectorizer = train_tfidf(dset)
# Out:
# 38325

# %%
vectorizer = train_tfidf(dset_new)
# Out:
# 26019

# %%
def avg_feature_vector(sentence, num_features=1):
    sentence = sentence.lower()
    words = sentence.split()
    feature_vec = np.zeros((1, num_features), dtype='float32')
    n_words = 0
    for word in words:
        if word in model:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if(n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
#     print feature_vec.shape
    return feature_vec

# %%
dump = pd.read_csv("dump.csv")
dump.head()
# Out:
#           L1                              L2                Key  \
# 0         AC      AC didn't cool fast enough                 AC
# 1         AC      AC remote wasn't available          AC-remote
# 2         AC        AC wasn't working at all                 AC
# 3         AC        Issue not mentioned here                 AC
# 4  Breakfast  Breakfast options were limited  Breakfast-options
#
#            Value       Department           Domain     Subject  \
# 0  not cool fast     Housekeeping      Maintenance  Appliance
# 1  not available     Housekeeping         Offering  Appliance
# 2    not working     Housekeeping      Maintenance  Appliance
# 3         issues     Housekeeping         Offering  Appliance
# 4        limited  Food & Beverage  Food Production   Breakfast
#
#                Attribute  Tf-idf  Video-GloVe
# 0  Integrity/Maintenance     NaN          NaN
# 1           Availability     NaN          NaN
# 2  Integrity/Maintenance     NaN          NaN
# 3              Readiness     NaN          NaN
# 4                Variety     NaN          NaN

# %%
clean_txt = []
for x in range(0, len(dump['L2'])):
    tmp = clean_review(dump['L2'][x]).split()
    res = [word.lower() for word in tmp if word.lower() not in stop_words]
    clean_txt.append(' '.join(res))

# %%
for x in range(2):
    s = dump['Domain'][x] + " " + dump['Subject'][x] + " " + clean_txt[x]
    print s
# Out:
# Maintenance Appliance  ac not cool fast enough
# Offering Appliance  ac remote not available

# %%
print len(clean_txt), len(dump['L2'])
# Out:
# 46 46

# %%
def check_cases(k,v,l1,s):
    if k.lower()=="staff" and v.lower() in ['rude', 'unhelpful']:
        return "MOT - Handling Guest Request At The Desk"
    elif k.lower()=="staff" and v.lower()=="not present":
        return "NOT FOUND"
    elif k.lower()=="room-service" and v.lower()=="delay":
        return "Servicing guest room (Occupied room)"
    elif k.lower() in ["walls", "mentioned room"] and v.lower() in ["seepage", "not allotted"]:
        return "Packing OOS Room Steps"
    elif v.lower() in ["insects", "rodent", "cockroach", "ant", "mosquito"]:
        return "Pest Control (Rodent management, cockroach management, ant management, fly management & mosquito man"
    elif s.lower()=="security":
        return "NOT FOUND"
    elif l1.lower()=="directions":
        return "NOT FOUND"
    elif k.lower()=="hot-water" or k.lower()=="running water" or k.lower()=="ac-remote":
        return "NOT FOUND"
    else:
        return None

# %%
def preprocess(inp):
    inp = inp.replace('Toiletry-kit', 'Replenishing supplies')
    inp = inp.replace('Washroom', 'Bathroom')
    inp = inp.replace('water-leakage', 'fittings fixtures check')
    inp = inp.replace('fixtures', 'fixtures check')
    return inp

# %%
def match_key(input, video):
    li = []
#     input = input.replace('Washroom', 'bathroom')
    words = set(input.lower().split())
    for x in range(0, len(video)):
        tmp = video[x].replace('Check In', 'check-in')
        token = tmp.lower().split()
        for word in words:
            if word in token:
                li.append(video[x])
                continue
    return li

# %%
print match_key("fittings fixtures", df['video_name'])
# Out:
# ['Bathroom Cleaning-Washbasin Cleaning(1)(Cleaning SS Fittings and Mirror)', 'Bathtub cleaning-Rinsing (fittings & fixtures & bathtub) & scrubbing (fittings & fixtures)', 'Fittings & fixtures cleaning process', 'Fittings & fixtures cleaning process', 'Fittings & Fixtures Checking process', 'Fittings & Fixtures Checking process']

# %%
def get_video_from_similarity2(inp, vectorizer, sent, num):
    cont = []
    porter = nltk.PorterStemmer()
    tk = word_tokenize(sent.lower())
    stem = [porter.stem(t) for t in tk]
    vec2 = vectorizer.transform([' '.join(stem)])
    s1 = "NOT FOUND"
    for x in range(0, len(inp)):
        token = word_tokenize(inp[x])
        words = [w.lower() for w in token if w.lower() not in stop_words]
        stem_token = [porter.stem(t) for t in words]
        vec = vectorizer.transform([' '.join(stem_token)])
        tmp = cosine_similarity(vec, vec2)
#         print tmp[0][0]
        s1 = inp[x]
        cont.append((tmp[0][0], s1))
    
    cont = sorted(cont, reverse=True)
    return cont[:num]

# %%
tfidf = []
for x in range(0, len(dump['Key'])):
    k,v,l1,s = dump['Key'][x], dump['Value'][x], dump['L1'][x], dump['Subject'][x]
    flag = check_cases(k,v,l1,s)
    if flag!=None:
        tfidf.append(flag)
    else:
        k = preprocess(k)
        v = preprocess(v)
        l1 = preprocess(l1)
        s = preprocess(s)
        if k != "Check-in":
            k = k.replace("-", " ")
        k = k.replace("/", " ")
        v = v.replace("-", " ")
        v = v.replace("/", " ")
        if s != "Check-in":
            s = s.replace('-', ' ')
        s = s.replace('/', ' ')
        l1 = l1.replace('/', ' ')
    #     print k,s,l1,'\n'
        li = match_key(k+" "+s+" "+l1, df['video_name'])
    #     print li
        res = get_video_from_glovesimilarity2(li, k+" "+v, 1)
        if(len(res)>0):
            tfidf.append(res[0][1])
        else:
            tfidf.append("NOT FOUND")

# %%
print len(tfidf)
# Out:
# 46

# %%
dump['Tf-idf'] = tfidf

# %%
def get_video_from_glovesimilarity2(inp, sent, num):
    vec2 = avg_feature_vector(sent)
    cont = []
    for x in range(0, len(inp)):
        token = word_tokenize(inp[x])
        words = [w.lower() for w in token if w.lower() not in stop_words]
        vec = avg_feature_vector(' '.join(words))
        tmp = cosine_similarity(vec, vec2)
        s1 = inp[x]
        cont.append((tmp[0][0], s1))
    cont = sorted(cont, reverse=True)
    return cont[:num]

# %%
glove = []
for x in range(0, len(dump['Key'])):
    k,v,l1,s = dump['Key'][x], dump['Value'][x], dump['L1'][x], dump['Subject'][x]
    flag = check_cases(k,v,l1,s)
    if flag != None:
        glove.append(flag)
    else:
        k = preprocess(k)
        v = preprocess(v)
        l1 = preprocess(l1)
        s = preprocess(s)
        if k != "Check-in":
            k = k.replace("-", " ")
        k = k.replace("/", " ")
        v = v.replace("-", " ")
        v = v.replace("/", " ")
        if s != "Check-in":
            s = s.replace('-', ' ')
        s = s.replace('/', ' ')
        l1 = l1.replace('/', ' ')
    #     print k,s,l1,'\n'
        li = match_key(k+" "+s+" "+l1, df['video_name'])
    #     print li
        res = get_video_from_glovesimilarity2(li, k+" "+v, 2)
        if(len(res)>1):
            glove.append(res[1][1])
        elif len(res)==1:
            glove.append(res[0][1])
        else:
            glove.append("NOT FOUND")

# %%
for x in range(len(glove)):
    print tfidf[x], "\t||\t", glove[x]
# Out:
# AC filter cleaning- Process & frequency 	||	AC filter cleaning- Process & frequency
# NOT FOUND 	||	NOT FOUND
# AC filter cleaning- Process & frequency 	||	AC filter cleaning- Process & frequency
# AC filter cleaning- Process & frequency 	||	AC filter cleaning- Process & frequency
# Breakfast Buffet Replenishment Clean Storage And Live Counter Setup 	||	Breakfast Buffet
# MOT - Breakfast Order Guest Says Yes 	||	Breakfast Buffet Replenishment Clean Storage And Live Counter Setup
# SERVICE OF PRE PLATED FOOD 	||	SERVICE OF STRAIGHT DRINK
# SERVICE OF PRE PLATED FOOD 	||	MOT - Breakfast Order Guest Says Yes
# SERVICE OF PRE PLATED FOOD 	||	Breakfast Buffet Replenishment Clean Storage And Live Counter Setup
# Breakfast Buffet Sections 	||	Breakfast Buffet
# Tab Check In - Allocating A Room & GRC Process 	||	Tab Check In - Upgrade Occupancy
# Tab Check In - Allocating A Room & GRC Process 	||	MOT - Guest Does Not Have A Valid ID At Check In
# Packing OOS Room Steps 	||	Packing OOS Room Steps
# MOT - Handling Multiple Guests At Reception 	||	Reception Area cleaning (Telephone & reception counter cleaning)
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# Pest Control (Rodent management, cockroach management, ant management, fly management & mosquito man 	||	Pest Control (Rodent management, cockroach management, ant management, fly management & mosquito man
# Occupied room set up (Things to do in an occupied room & bathroom) 	||	Entering the guest room to clean process
# Linen Exchange & Discard Process (Handing over soiled linen & Receiving fresh linen) 	||	Removing soiled linen process
# MOT - Check In Shown In A Dirty Room 	||	Vacant room set up (Things to do in a vacant room & bathroom)
# Packing OOS Room Steps 	||	Packing OOS Room Steps
# Servicing guest room (Occupied room) 	||	Servicing guest room (Occupied room)
# MOT - Handling Guest Request At The Desk 	||	MOT - Handling Guest Request At The Desk
# SERVICE OF PRE PLATED FOOD 	||	SERVICE OF STRAIGHT DRINK
# NOT FOUND 	||	NOT FOUND
# Replenishing supplies & Mopping process 	||	Replenishing supplies & Mopping process
# Replenishing supplies & Mopping process 	||	Replenishing supplies & Mopping process
# Room Layout & Amenities (Main door,switches & TV area & bed area)  	||	Room Layout & Amenities (Main door,switches & TV area & bed area)
# Room Layout & Amenities (Main door,switches & TV area & bed area)  	||	Dusting (Window, wooden panel & TV cleaning)
# Room Layout & Amenities (Main door,switches & TV area & bed area)  	||	Dusting (Window, wooden panel & TV cleaning)
# Dusting (Window, wooden panel & TV cleaning) 	||	Room Layout & Amenities (Main door,switches & TV area & bed area)
# Fittings & Fixtures Checking process 	||	Fittings & fixtures cleaning process
# NOT FOUND 	||	NOT FOUND
# Bathroom Cleaning-Preparing To Clean 	||	Bathroom Layout (Washbasin area, shower area & bathroom linen)
# NOT FOUND 	||	NOT FOUND
# Linen Exchange & Discard Process (Handing over soiled linen & Receiving fresh linen) 	||	Bathroom Cleaning-Preparing To Clean
# Linen Exchange & Discard Process (Handing over soiled linen & Receiving fresh linen) 	||	Bathroom Cleaning-Preparing To Clean
# Bathroom Cleaning-Preparing To Clean 	||	Bathroom Layout (Washbasin area, shower area & bathroom linen)
# Fittings & Fixtures Checking process 	||	Fittings & Fixtures Checking process
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND
# NOT FOUND 	||	NOT FOUND

# %%
print len(glove)
# Out:
# 46

# %%
dump['Video-GloVe2'] = glove

# %%
dump
# Out:
#                         L1                                      L2  \
# 0                       AC              AC didn't cool fast enough
# 1                       AC              AC remote wasn't available
# 2                       AC                AC wasn't working at all
# 3                       AC                Issue not mentioned here
# 4                Breakfast          Breakfast options were limited
# 5                Breakfast               Breakfast wasn't provided
# 6                Breakfast              Delay in breakfast service
# 7                Breakfast                Food quality wasn't good
# 8                Breakfast       Food quantity wasn't satisfactory
# 9                Breakfast                Issue not mentioned here
# 10     Check-in experience               Delay in check-in process
# 11     Check-in experience                Issue not mentioned here
# 12     Check-in experience          Mentioned room wasn't allotted
# 13     Check-in experience      Reception staff was rude/unhelpful
# 14     Check-in experience       Staff wasn't present at reception
# 15              Directions       Map link to the OYO was incorrect
# 16              Directions               No OYO board at the hotel
# 17              Directions  Unable to contact hotel for directions
# 18  Room/Linen Cleanliness                     Insects in the room
# 19  Room/Linen Cleanliness                Issue not mentioned here
# 20  Room/Linen Cleanliness                     Linen was not clean
# 21  Room/Linen Cleanliness             Overall, the room was dirty
# 22  Room/Linen Cleanliness            Seepage on walls in the room
# 23       Staff and Service                   Delay in room service
# 24       Staff and Service                    Hotel staff was rude
# 25       Staff and Service                Issue not mentioned here
# 26       Staff and Service            Security issues in the hotel
# 27            Toiletry Kit                Issue not mentioned here
# 28            Toiletry Kit               Toiletry Kit not provided
# 29                      TV     Desired channels were not available
# 30                      TV               DTH/Cable was not working
# 31                      TV                Issue not mentioned here
# 32                      TV               Picture and sound quality
# 33                Washroom         Broken fixtures in the washroom
# 34                Washroom              Hot water wasn't available
# 35                Washroom                Issue not mentioned here
# 36                Washroom          Running water wasn't available
# 37                Washroom                       Towels were dirty
# 38                Washroom                Towels were not provided
# 39                Washroom                      Washroom was dirty
# 40                Washroom           Water leakage in the washroom
# 41                    WiFi               Could not connect to WiFi
# 42                    WiFi                Issue not mentioned here
# 43                    WiFi                     Very low data limit
# 44                    WiFi           WiFi password wasn't provided
# 45                    WiFi              WiFi was working very slow
#
#                   Key               Value       Department  \
# 0                  AC       not cool fast     Housekeeping
# 1           AC-remote       not available     Housekeeping
# 2                  AC         not working     Housekeeping
# 3                  AC              issues     Housekeeping
# 4   Breakfast-options             limited  Food & Beverage
# 5           Breakfast        not provided  Food & Beverage
# 6   Breakfast-service               delay  Food & Beverage
# 7        Food-quality            not good  Food & Beverage
# 8       Food-quantity          not enough  Food & Beverage
# 9           Breakfast              issues  Food & Beverage
# 10           Check-in               delay     Front Office
# 11           Check-in              issues     Front Office
# 12     Mentioned Room        not allotted     Front Office
# 13    Reception-Staff  rude and unhelpful     Front Office
# 14              Staff         not present     Front Office
# 15           Map-link           incorrect     Front Office
# 16          oyo-board                  no     Front Office
# 17              hotel   unable to contact     Front Office
# 18               room             insects     Housekeeping
# 19               room              issues     Housekeeping
# 20              linen           not clean     Housekeeping
# 21               room               dirty     Housekeeping
# 22              walls             seepage     Housekeeping
# 23       room-service               delay     Housekeeping
# 24              staff                rude     Front Office
# 25              staff              issues     Front Office
# 26              hotel     security issues     Front Office
# 27       Toiletry-kit              issues     Housekeeping
# 28       Toiletry-kit        not provided     Housekeeping
# 29   Desired-channels       not available     Housekeeping
# 30          DTH/cable         not working     Housekeeping
# 31                 TV              issues     Housekeeping
# 32                 TV             quality     Housekeeping
# 33           fixtures              broken     Housekeeping
# 34          hot-water       not available     Housekeeping
# 35           washroom              issues     Housekeeping
# 36      running water       not available     Housekeeping
# 37             towels               dirty     Housekeeping
# 38             towels        not provided     Housekeeping
# 39           washroom               dirty     Housekeeping
# 40      water-leakage            washroom     Housekeeping
# 41               wifi         not connect     Front Office
# 42               wifi              issues     Front Office
# 43         data-limit            very low     Front Office
# 44      wifi-password        not provided     Front Office
# 45               wifi                slow     Front Office
#
#                 Domain       Subject                Attribute  \
# 0          Maintenance    Appliance     Integrity/Maintenance
# 1             Offering    Appliance              Availability
# 2          Maintenance    Appliance     Integrity/Maintenance
# 3             Offering    Appliance                 Readiness
# 4      Food Production     Breakfast                  Variety
# 5              Service     Breakfast                 Accuracy
# 6              Service         Staff               Efficiency
# 7      Food Production     Breakfast                  Quality
# 8      Food Production     Breakfast                     Size
# 9             Offering     Breakfast  Food & Beverage Quality
# 10  Check-in/Check-out      Check-in               Efficiency
# 11  Check-in/Check-out      Check-in     Front Office Quality
# 12  Check-in/Check-out          Room                 Accuracy
# 13             Service         Staff                 Courtesy
# 14          Front Desk         Staff                 Accuracy
# 15            Offering      location                 Accuracy
# 16          Front Desk       Signage                 Accuracy
# 17          Front Desk    Phone Call                 Accuracy
# 18         Room Making          Room             Pest-control
# 19         Room Making          Room    House Keeping Quality
# 20         Room Making         Linen              Cleanliness
# 21         Room Making          Room              Cleanliness
# 22         Room Making       Surface              Cleanliness
# 23             Service         Staff               Efficiency
# 24             Service         Staff                 Courtesy
# 25             Service         Staff     Front Office Quality
# 26             Service      Security                 Accuracy
# 27         Room Making     Amenities    House Keeping Quality
# 28            Offering     Amenities             Availability
# 29            Offering     Amenities             Availability
# 30         Maintenance     Appliance    Integrity/Maintenance
# 31            Offering     Appliance    House Keeping Quality
# 32         Maintenance     Appliance    Integrity/Maintenance
# 33         Maintenance      Washroom    Integrity/Maintenance
# 34            Offering         Water             Availability
# 35         Maintenance      Washroom    House Keeping Quality
# 36         Maintenance  Water Supply             Availability
# 37         Room Making         Linen              Cleanliness
# 38         Room Making         Linen             Availability
# 39         Room Making      Washroom              Cleanliness
# 40         Maintenance      Washroom    Integrity/Maintenance
# 41          Front Desk      Internet                  Quality
# 42          Front Desk      Internet     Front Office Quality
# 43          Front Desk      Internet             Availability
# 44          Front Desk      Internet             Availability
# 45          Front Desk      Internet                  Quality
#
#                                                Tf-idf  \
# 0             AC filter cleaning- Process & frequency
# 1                                           NOT FOUND
# 2             AC filter cleaning- Process & frequency
# 3             AC filter cleaning- Process & frequency
# 4   Breakfast Buffet Replenishment Clean Storage A...
# 5                MOT - Breakfast Order Guest Says Yes
# 6                          SERVICE OF PRE PLATED FOOD
# 7                          SERVICE OF PRE PLATED FOOD
# 8                          SERVICE OF PRE PLATED FOOD
# 9                           Breakfast Buffet Sections
# 10     Tab Check In - Allocating A Room & GRC Process
# 11     Tab Check In - Allocating A Room & GRC Process
# 12                             Packing OOS Room Steps
# 13        MOT - Handling Multiple Guests At Reception
# 14                                          NOT FOUND
# 15                                          NOT FOUND
# 16                                          NOT FOUND
# 17                                          NOT FOUND
# 18  Pest Control (Rodent management, cockroach man...
# 19  Occupied room set up (Things to do in an occup...
# 20  Linen Exchange & Discard Process (Handing over...
# 21               MOT - Check In Shown In A Dirty Room
# 22                             Packing OOS Room Steps
# 23               Servicing guest room (Occupied room)
# 24           MOT - Handling Guest Request At The Desk
# 25                         SERVICE OF PRE PLATED FOOD
# 26                                          NOT FOUND
# 27            Replenishing supplies & Mopping process
# 28            Replenishing supplies & Mopping process
# 29  Room Layout & Amenities (Main door,switches & ...
# 30  Room Layout & Amenities (Main door,switches & ...
# 31  Room Layout & Amenities (Main door,switches & ...
# 32       Dusting (Window, wooden panel & TV cleaning)
# 33               Fittings & Fixtures Checking process
# 34                                          NOT FOUND
# 35               Bathroom Cleaning-Preparing To Clean
# 36                                          NOT FOUND
# 37  Linen Exchange & Discard Process (Handing over...
# 38  Linen Exchange & Discard Process (Handing over...
# 39               Bathroom Cleaning-Preparing To Clean
# 40               Fittings & Fixtures Checking process
# 41                                          NOT FOUND
# 42                                          NOT FOUND
# 43                                          NOT FOUND
# 44                                          NOT FOUND
# 45                                          NOT FOUND
#
#                                           Video-GloVe  \
# 0             AC filter cleaning- Process & frequency
# 1                                           NOT FOUND
# 2             AC filter cleaning- Process & frequency
# 3             AC filter cleaning- Process & frequency
# 4   Breakfast Buffet Replenishment Clean Storage A...
# 5                MOT - Breakfast Order Guest Says Yes
# 6                          SERVICE OF PRE PLATED FOOD
# 7                          SERVICE OF PRE PLATED FOOD
# 8                          SERVICE OF PRE PLATED FOOD
# 9                           Breakfast Buffet Sections
# 10     Tab Check In - Allocating A Room & GRC Process
# 11     Tab Check In - Allocating A Room & GRC Process
# 12                             Packing OOS Room Steps
# 13        MOT - Handling Multiple Guests At Reception
# 14                                          NOT FOUND
# 15                                          NOT FOUND
# 16                                          NOT FOUND
# 17                                          NOT FOUND
# 18  Pest Control (Rodent management, cockroach man...
# 19  Occupied room set up (Things to do in an occup...
# 20  Linen Exchange & Discard Process (Handing over...
# 21               MOT - Check In Shown In A Dirty Room
# 22                             Packing OOS Room Steps
# 23               Servicing guest room (Occupied room)
# 24           MOT - Handling Guest Request At The Desk
# 25                         SERVICE OF PRE PLATED FOOD
# 26                                          NOT FOUND
# 27            Replenishing supplies & Mopping process
# 28            Replenishing supplies & Mopping process
# 29  Room Layout & Amenities (Main door,switches & ...
# 30  Room Layout & Amenities (Main door,switches & ...
# 31  Room Layout & Amenities (Main door,switches & ...
# 32       Dusting (Window, wooden panel & TV cleaning)
# 33               Fittings & Fixtures Checking process
# 34                                          NOT FOUND
# 35               Bathroom Cleaning-Preparing To Clean
# 36                                          NOT FOUND
# 37  Linen Exchange & Discard Process (Handing over...
# 38  Linen Exchange & Discard Process (Handing over...
# 39               Bathroom Cleaning-Preparing To Clean
# 40               Fittings & Fixtures Checking process
# 41                                          NOT FOUND
# 42                                          NOT FOUND
# 43                                          NOT FOUND
# 44                                          NOT FOUND
# 45                                          NOT FOUND
#
#                                          Video-GloVe2
# 0             AC filter cleaning- Process & frequency
# 1                                           NOT FOUND
# 2             AC filter cleaning- Process & frequency
# 3             AC filter cleaning- Process & frequency
# 4                                    Breakfast Buffet
# 5   Breakfast Buffet Replenishment Clean Storage A...
# 6                           SERVICE OF STRAIGHT DRINK
# 7                MOT - Breakfast Order Guest Says Yes
# 8   Breakfast Buffet Replenishment Clean Storage A...
# 9                                    Breakfast Buffet
# 10                   Tab Check In - Upgrade Occupancy
# 11   MOT - Guest Does Not Have A Valid ID At Check In
# 12                             Packing OOS Room Steps
# 13  Reception Area cleaning (Telephone & reception...
# 14                                          NOT FOUND
# 15                                          NOT FOUND
# 16                                          NOT FOUND
# 17                                          NOT FOUND
# 18  Pest Control (Rodent management, cockroach man...
# 19           Entering the guest room to clean process
# 20                      Removing soiled linen process
# 21  Vacant room set up (Things to do in a vacant r...
# 22                             Packing OOS Room Steps
# 23               Servicing guest room (Occupied room)
# 24           MOT - Handling Guest Request At The Desk
# 25                          SERVICE OF STRAIGHT DRINK
# 26                                          NOT FOUND
# 27            Replenishing supplies & Mopping process
# 28            Replenishing supplies & Mopping process
# 29  Room Layout & Amenities (Main door,switches & ...
# 30       Dusting (Window, wooden panel & TV cleaning)
# 31       Dusting (Window, wooden panel & TV cleaning)
# 32  Room Layout & Amenities (Main door,switches & ...
# 33               Fittings & fixtures cleaning process
# 34                                          NOT FOUND
# 35  Bathroom Layout (Washbasin area, shower area &...
# 36                                          NOT FOUND
# 37               Bathroom Cleaning-Preparing To Clean
# 38               Bathroom Cleaning-Preparing To Clean
# 39  Bathroom Layout (Washbasin area, shower area &...
# 40               Fittings & Fixtures Checking process
# 41                                          NOT FOUND
# 42                                          NOT FOUND
# 43                                          NOT FOUND
# 44                                          NOT FOUND
# 45                                          NOT FOUND

# %%
# def get_comb(inp, vectorizer, sent, num, flag):
#     cont = []
#     ret = []
#     porter = nltk.PorterStemmer()
#     tk = word_tokenize(sent.lower())
#     stem = [porter.stem(t) for t in tk]
#     v = vectorizer.transform([' '.join(stem)])
#     v2 = avg_feature_vector(sent)
#     for x in range(0, len(inp)):
#         token = word_tokenize(inp[x])
#         words = [w.lower() for w in token if w.lower() not in stop_words]
#         stem_token = [porter.stem(t) for t in words]
#         vec = vectorizer.transform([' '.join(stem_token)])
#         vec2 = avg_feature_vector(inp[x])
#         tmp = cosine_similarity(vec, v)
#         tmp2 = cosine_similarity(vec2, v2)
# #         print tmp[0][0]
#         s1 = inp[x]
#         if(flag==1):
#             cont.append((tmp[0][0], s1))
# #         else:
#             cont.append((tmp2[0][0], s1))
#     cont = sorted(cont, reverse=True)
#     return cont[:num]

# %%
# comb = []
# for x in range(0, len(dump['Key'])):
#     k,v,s = dump['Key'][x], dump['Value'][x], dump['L1'][x]
#     k = k.replace("-", " ")
#     k = k.replace("/", " ")
#     v = v.replace("-", " ")
#     v = v.replace("/", " ")
#     s = s.replace('-', ' ')
#     s = s.replace('/', ' ')
    
#     li = get_comb(df['video_name'], vectorizer, s+" "+k, 10, 1)
   
#     new_li = []
#     for fi, se in li:
#         new_li.append(se)
# #     print new_li
#     res = get_comb(new_li, vectorizer, k+" "+v, 1, 0)

#     comb.append(res[0][1])

# %%
from pandas import ExcelWriter

writer = ExcelWriter('PythonExport.xlsx')
dump.to_excel(writer,'Sheet5')
writer.save()
